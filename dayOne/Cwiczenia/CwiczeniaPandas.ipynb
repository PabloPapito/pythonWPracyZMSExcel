# %% [markdown]
# # Ćwiczenia Pandas

# %% [markdown]
# #### Ćwiczenie 1. - Pandas

# %%
# Stwórz DataFrame:
    # Użyj biblioteki pandas i numpy, aby stworzyć DataFrame df_cw.
    # Skorzystaj z funkcji np.random.randint(), aby wygenerować losowe liczby całkowite z zakresu od 0 do 100. Wygeneruj 5 wierszy i 3 kolumny. Nazwij kolumny jako 'A', 'B', i 'C'.

# Zadanie 1: Wyświetl informacje o danych w DataFrame:
    # Skorzystaj z metody info(), aby uzyskać szczegółowe informacje o strukturze danych w DataFrame. Informacje obejmują m.in. liczbę wierszy i kolumn, typy danych oraz brakujące wartości.
    # Bezpośrednio wywołaj metodę df_cw.info(), ponieważ nie zwraca ona wyniku do przypisania do zmiennej.

# Zadanie 2: Wyświetl trzy pierwsze wiersze DataFrame:
    # Użyj metody head(), aby wyświetlić trzy pierwsze wiersze DataFrame. Przekaż do metody parametr 3, aby wyświetlić dokładnie trzy wiersze.
    # Przypisz wynik do zmiennej pierwsze_wiersze_cw.

# Wyświetl wyniki:
    # Wydrukuj tekst „Trzy pierwsze wiersze DataFrame” oraz zmienną pierwsze_wiersze_cw.

# %%
import pandas as pd
import numpy as np

# Ćwiczenie 1: Stworzenie DataFrame z danymi losowymi
df_cw = pd.DataFrame(np.random.randint(0, 100, size=(5, 3)), columns=['A', 'B', 'C'])

# Zadanie 1: Wyświetlenie informacji o danych w DataFrame
info_dane_cw = # Tu dodaj kod

# Zadanie 2: Wyświetlenie trzech pierwszych wierszy DataFrame
pierwsze_wiersze_cw = # Tu dodaj kod

# Wyświetlenie wyników
print("Informacje o danych:", info_dane_cw)
print("Trzy pierwsze wiersze DataFrame:\n", pierwsze_wiersze_cw)

# %% [markdown]
# #### Ćwiczenie 2. - Wczytywanie i zapis danych

# %%
# Wczytaj dane z pliku CSV:
    # Użyj biblioteki pandas do wczytania danych z pliku CSV.
    # Skorzystaj z funkcji pd.read_csv(), aby wczytać dane z pliku CSV i przypisz wynik do zmiennej df_wczytane_cw.
        # Podaj odpowiednią ścieżkę do pliku CSV (np. 'nazwa_pliku.csv').

# Zadanie 1: Wyświetl pięć pierwszych wierszy wczytanych danych:
    # Skorzystaj z metody head(5), aby wyświetlić pięć pierwszych wierszy wczytanych danych.
    # Wynik przypisz do zmiennej pierwsze_wiersze_wczytane_cw.

# Zadanie 2: Zapisz dane do pliku Excel:
    # Skorzystaj z metody to_excel(), aby zapisać wczytane dane do pliku Excel.
    # Nazwij plik jako 'dane_wczytane.xlsx'. Ustaw parametr index=False, aby nie dodawać indeksów do pliku Excel.

# Wyświetl wyniki:
    # Wydrukuj pięć pierwszych wierszy wczytanych danych oraz komunikat potwierdzający zapis danych do pliku Excel.

# %%
import pandas as pd

# Ćwiczenie 2: Wczytanie danych z pliku CSV
df_wczytane_cw = # Tu dodaj kod

# Zadanie 1: Wyświetlenie pięciu pierwszych wierszy wczytanych danych
pierwsze_wiersze_wczytane_cw = # Tu dodaj kod

# Zadanie 2: Zapisanie wczytanych danych do pliku Excel
# (Uwaga: Dla potrzeb ćwiczenia, możesz użyć tych samych wczytanych danych)
df_wczytane_cw.to_excel('dane_wczytane.xlsx', index=False)

# Wyświetlenie wyników
print("Pięć pierwszych wierszy wczytanych danych:\n", pierwsze_wiersze_wczytane_cw)
print("Dane zostały zapisane do pliku Excel.")

# %% [markdown]
# #### Ćwiczenie 3. - Atrybuty DataFrame w Pandas

# %%
# Stwórz DataFrame:
    # Użyj biblioteki pandas, aby stworzyć DataFrame o nazwie df_cw.
    # DataFrame powinien zawierać dwie kolumny: 'A' z wartościami [1, 2, 3] oraz 'B' z wartościami [4, 5, 6].

# Zadanie 1: Wyświetl kształt DataFrame:
    # Skorzystaj z atrybutu shape, aby uzyskać kształt DataFrame (liczbę wierszy i kolumn).
    # Wynik przypisz do zmiennej ksztalt_cw.

# Zadanie 2: Wyświetl indeksy wierszy DataFrame:
    # Użyj atrybutu index, aby wyświetlić indeksy wierszy DataFrame.
    # Wynik przypisz do zmiennej indeksy_cw.

# Zadanie 3: Wyświetl etykiety kolumn DataFrame:
    # Użyj atrybutu columns, aby wyświetlić etykiety kolumn DataFrame.
    # Wynik przypisz do zmiennej etykiety_kolumn_cw.

# Zadanie 4: Wyświetl typy danych kolumn DataFrame:
    # Użyj atrybutu dtypes, aby wyświetlić typy danych w każdej kolumnie DataFrame.
    # Wynik przypisz do zmiennej typy_danych_cw.

# Wyświetl wyniki:
    # Wydrukuj kształt, indeksy wierszy, etykiety kolumn oraz typy danych.

# %%
import pandas as pd

# Ćwiczenie 3: Sprawdzenie kształtu i struktury DataFrame
df_cw = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})

# Zadanie 1: Wyświetlenie kształtu DataFrame
ksztalt_cw = # Tu dodaj kod

# Zadanie 2: Wyświetlenie indeksów wierszy DataFrame
indeksy_cw = # Tu dodaj kod

# Zadanie 3: Wyświetlenie etykiet kolumn DataFrame
etykiety_kolumn_cw = # Tu dodaj kod

# Zadanie 4: Wyświetlenie typów danych kolumn DataFrame
typy_danych_cw = # Tu dodaj kod

# Wyświetlenie wyników
print("Kształt DataFrame:", ksztalt_cw)
print("Indeksy wierszy DataFrame:", indeksy_cw)
print("Etykiety kolumn DataFrame:", etykiety_kolumn_cw)
print("Typy danych kolumn DataFrame:\n", typy_danych_cw)

# %% [markdown]
# #### Ćwiczenie 4. - Przydatne funkcje w Pandas

# %%
# Stwórz DataFrame:
    # Użyj biblioteki pandas, aby stworzyć DataFrame o nazwie df_cw.
    # DataFrame powinien zawierać trzy kolumny:
    # 'A' z wartościami [1, 2, 3, 4, 5],
    # 'B' z wartościami ['a', 'b', 'c', 'd', 'e'],
    # 'C' z wartościami [0.1, 0.5, 0.8, 0.3, 0.9].

# Zadanie 1: Uzyskaj opis statystyczny dla DataFrame:
    # Skorzystaj z metody describe(), aby uzyskać podstawowy opis statystyczny (liczba elementów, średnia, odchylenie standardowe, wartości minimalne i maksymalne) dla danych numerycznych w DataFrame.
    # Przypisz wynik do zmiennej opis_statystyczny_cw.

# Zadanie 2: Wyświetl informacje o danych w DataFrame:
    # Skorzystaj z metody info(), aby uzyskać informacje o typach danych, liczbie wierszy, liczbie brakujących wartości itp.
    # Bezpośrednio wywołaj df_cw.info(), ponieważ info() nie zwraca wartości, a jedynie drukuje informacje.

# Zadanie 3: Wyświetl trzy pierwsze wiersze DataFrame:
    # Skorzystaj z metody head(), aby wyświetlić trzy pierwsze wiersze DataFrame.
    # Przypisz wynik do zmiennej pierwsze_wiersze_cw.

# Zadanie 4: Wyświetl trzy ostatnie wiersze DataFrame:
    # Skorzystaj z metody tail(), aby wyświetlić trzy ostatnie wiersze DataFrame.
    # Przypisz wynik do zmiennej ostatnie_wiersze_cw.

# Zadanie 5:
    # Wyświetl trzy losowe wiersze DataFrame:
    # Skorzystaj z metody sample(), aby wyświetlić trzy losowo wybrane wiersze z DataFrame.
    # Przypisz wynik do zmiennej losowe_wiersze_cw.

# Wyświetl wyniki:
    # Wydrukuj wyniki z wszystkich powyższych zadań.

# %%
# Ćwiczenie 4: Użycie funkcji describe, info, head, tail, sample
df_cw = pd.DataFrame({'A': [1, 2, 3, 4, 5],
                      'B': ['a', 'b', 'c', 'd', 'e'],
                      'C': [0.1, 0.5, 0.8, 0.3, 0.9]})

# Zadanie 1: Uzyskanie opisu statystycznego dla DataFrame
opis_statystyczny_cw = # Tu dodaj kod

# Zadanie 2: Wyświetlenie informacji o danych w DataFrame
informacje_o_danych_cw = # Tu dodaj kod

# Zadanie 3: Wyświetlenie trzech pierwszych wierszy DataFrame
pierwsze_wiersze_cw = # Tu dodaj kod

# Zadanie 4: Wyświetlenie trzech ostatnich wierszy DataFrame
ostatnie_wiersze_cw = # Tu dodaj kod

# Zadanie 5: Wyświetlenie trzech losowych wierszy DataFrame
losowe_wiersze_cw = # Tu dodaj kod

# Wyświetlenie wyników
print("Opis statystyczny DataFrame:\n", opis_statystyczny_cw)
print("Informacje o danych w DataFrame:\n", informacje_o_danych_cw)
print("Trzy pierwsze wiersze DataFrame:\n", pierwsze_wiersze_cw)
print("Trzy ostatnie wiersze DataFrame:\n", ostatnie_wiersze_cw)
print("Trzy losowe wiersze DataFrame:\n", losowe_wiersze_cw)

# %% [markdown]
# #### Ćwiczenie 5. - Sortowanie Danych w Pandas

# %%
# Stwórz DataFrame:
    # Użyj biblioteki pandas, aby stworzyć DataFrame o nazwie df_cw.
    # DataFrame powinien zawierać kolumnę 'A' z wartościami [3, 1, 4, 2] oraz kolumnę 'B' z wartościami ['c', 'a', 'd', 'b'].

# Zadanie 1: Posortuj wiersze według kolumny 'A':
    # Skorzystaj z metody sort_values() z argumentem by='A', aby posortować wiersze DataFrame według wartości w kolumnie 'A' rosnąco.
    # Wynik przypisz do zmiennej df_posortowany_cw.

# Zadanie 2: Posortuj kolumny według etykiet:
    # Skorzystaj z metody sort_index() z argumentem axis=1, aby posortować kolumny według ich nazw (etykiet).
    # Wynik przypisz do zmiennej df_kolumny_posortowane_cw.

# Zadanie 3: Posortuj wiersze malejąco według kolumny 'A':
    # Skorzystaj z metody sort_values() z argumentem by='A' oraz ascending=False, aby posortować wiersze DataFrame według wartości w kolumnie 'A' malejąco.
    # Wynik przypisz do zmiennej df_posortowany_malejaco_cw.

# Wyświetl wyniki:
    # Wydrukuj DataFrame po każdym z powyższych rodzajów sortowania.

# %%
# Ćwiczenie 5: Sortowanie danych w Pandas
df_cw = pd.DataFrame({'A': [3, 1, 4, 2],
                      'B': ['c', 'a', 'd', 'b']})

# Zadanie 1: Sortowanie wierszy według kolumny 'A'
df_posortowany_cw = # Tu dodaj kod

# Zadanie 2: Sortowanie kolumn według etykiet
df_kolumny_posortowane_cw = # Tu dodaj kod

# Zadanie 3: Sortowanie wierszy malejąco według kolumny 'A'
df_posortowany_malejaco_cw = # Tu dodaj kod

# Wyświetlenie wyników
print("DataFrame po posortowaniu wierszy według kolumny 'A':\n", df_posortowany_cw)
print("DataFrame po posortowaniu kolumn według etykiet:\n", df_kolumny_posortowane_cw)
print("DataFrame po posortowaniu malejąco według kolumny 'A':\n", df_posortowany_malejaco_cw)

# %% [markdown]
# #### Ćwiczenie 6. - Filtrowanie Danych w Pandas

# %%
# Stwórz DataFrame:
    # Użyj biblioteki pandas, aby stworzyć DataFrame o nazwie df_cw.
    # DataFrame powinien zawierać kolumnę 'A' z wartościami [1, 2, 3, 4] oraz kolumnę 'B' z wartościami ['a', 'b', 'c', 'd']. Ustaw indeksy jako ['x', 'y', 'z', 'w'].

# Zadanie 1: Filtrowanie za pomocą loc:
    # Skorzystaj z metody loc[], aby wybrać wiersze o indeksach 'x' i 'y' oraz kolumnę 'A'.
    # Wynik przypisz do zmiennej df_filtr_loc_cw.

# Zadanie 2: Filtrowanie za pomocą iloc:
    # Skorzystaj z metody iloc[], aby wybrać pierwsze dwa wiersze oraz pierwszą kolumnę.
    # Wynik przypisz do zmiennej df_filtr_iloc_cw.

# Zadanie 3: Filtrowanie za pomocą query:
    # Skorzystaj z metody query(), aby wybrać wiersze, gdzie wartość w kolumnie 'A' jest większa niż 2.
    # Wynik przypisz do zmiennej df_filtr_query_cw.

# Zadanie 4: Filtrowanie za pomocą where:
    # Skorzystaj z metody where(), aby stworzyć nowy DataFrame, w którym wartości spełniające warunek zostaną zachowane, a pozostałe zastąpione NaN. Filtrowanie ma dotyczyć wartości w kolumnie 'A' większych niż 2.
    # Wynik przypisz do zmiennej df_filtr_where_cw.

# Zadanie 5: Filtrowanie za pomocą isin:
    # Skorzystaj z metody isin(), aby wybrać wiersze, gdzie wartość w kolumnie 'B' jest jedną z określonych wartości, np. ['a', 'c'].
    # Wynik przypisz do zmiennej df_filtr_isin_cw.

# Zadanie 6: Filtrowanie za pomocą isnull:
    # Skorzystaj z metody isnull(), aby wybrać wiersze, gdzie wartość w kolumnie 'A' jest NaN.
    # Wynik przypisz do zmiennej df_filtr_isnull_cw.

# Zadanie 7: Filtrowanie za pomocą notnull:
    # Skorzystaj z metody notnull(), aby wybrać wiersze, gdzie wartość w kolumnie 'A' nie jest NaN.
    # Wynik przypisz do zmiennej df_filtr_notnull_cw.

# Wyświetl wyniki:
    # Wydrukuj wyniki filtrowania z każdej metody: loc, iloc, query, where, isin, isnull, notnull.

# %%
# Ćwiczenie 6: Filtrowanie danych w Pandas
df_cw = pd.DataFrame({'A': [1, 2, 3, 4],
                      'B': ['a', 'b', 'c', 'd']}, index=['x', 'y', 'z', 'w'])

# Zadanie 1: Filtrowanie wierszy o indeksach 'x' i 'y' oraz kolumny 'A'
df_filtr_loc_cw = # Tu dodaj kod

# Zadanie 2: Filtrowanie pierwszych dwóch wierszy oraz pierwszej kolumny za pomocą iloc
df_filtr_iloc_cw = # Tu dodaj kod

# Zadanie 3: Filtrowanie wierszy, gdzie wartość w kolumnie 'A' jest większa niż 2 za pomocą query
df_filtr_query_cw = # Tu dodaj kod

# Zadanie 4: Filtrowanie, zwracając nowy DataFrame z wartościami, które spełniają warunek, a reszta to NaN za pomocą where
df_filtr_where_cw = # Tu dodaj kod

# Zadanie 5: Filtrowanie wierszy, gdzie wartość w kolumnie 'B' jest jedną z określonych wartości za pomocą isin
df_filtr_isin_cw = # Tu dodaj kod

# Zadanie 6: Filtrowanie wierszy, gdzie wartość w kolumnie 'A' jest NaN za pomocą isnull
df_filtr_isnull_cw = # Tu dodaj kod

# Zadanie 7: Filtrowanie wierszy, gdzie wartość w kolumnie 'A' nie jest NaN za pomocą notnull
df_filtr_notnull_cw = # Tu dodaj kod

# Wyświetlenie wyników
print("Wynik filtrowania za pomocą loc:\n", df_filtr_loc_cw)
print("Wynik filtrowania za pomocą iloc:\n", df_filtr_iloc_cw)
print("Wynik filtrowania za pomocą query:\n", df_filtr_query_cw)
print("Wynik filtrowania za pomocą where:\n", df_filtr_where_cw)
print("Wynik filtrowania za pomocą isin:\n", df_filtr_isin_cw)
print("Wynik filtrowania za pomocą isnull:\n", df_filtr_isnull_cw)
print("Wynik filtrowania za pomocą notnull:\n", df_filtr_notnull_cw)

# %% [markdown]
# #### Ćwiczenie 7. - Grupowanie Danych w Pandas

# %%
# Stwórz DataFrame:
    # Użyj biblioteki pandas, aby stworzyć DataFrame o nazwie df_cw.
    # DataFrame powinien zawierać kolumnę 'Category' z wartościami ['A', 'B', 'A', 'B', 'A', 'B'] oraz kolumnę 'Value' z wartościami [10, 20, 30, 40, 50, 60].

# Zadanie 1: Grupowanie na podstawie jednej kolumny i obliczanie sumy dla każdej grupy:
    # Skorzystaj z metody groupby(), aby pogrupować dane na podstawie kolumny 'Category', a następnie oblicz sumę wartości w każdej grupie.
    # Użyj sum(), aby obliczyć sumy.
    # Wynik przypisz do zmiennej grupowanie_jedna_kolumna_cw.

# Zadanie 2: Grupowanie na podstawie wielu kolumn i obliczanie sumy dla każdej grupy:
    # Jeśli chcesz grupować na podstawie wielu kolumn, użyj groupby() z listą kolumn. W tym przykładzie użyj tylko jednej kolumny, 'Category', ponieważ druga kolumna to wartości liczbowe.
    # Wynik przypisz do zmiennej grupowanie_wiele_kolumn_cw.

# Zadanie 3: Grupowanie i obliczanie różnych statystyk dla każdej grupy:
    # Skorzystaj z metody agg(), aby zastosować różne operacje (np. sumę, średnią) dla każdej grupy.
    # Wynik przypisz do zmiennej grupowanie_statystyki_cw.

# Wyświetl wyniki:
    # Wydrukuj wyniki grupowania dla każdego z powyższych zadań: grupowanie na podstawie jednej kolumny, grupowanie na podstawie wielu kolumn oraz grupowanie z różnymi operacjami.

# %%
# Ćwiczenie 7: Grupowanie danych w Pandas
df_cw = pd.DataFrame({'Category': ['A', 'B', 'A', 'B', 'A', 'B'],
                      'Value': [10, 20, 30, 40, 50, 60]})

# Zadanie 1: Grupowanie na podstawie kolumny 'Category' i obliczanie sumy dla każdej grupy
grupowanie_jedna_kolumna_cw = # Tu dodaj kod

# Zadanie 2: Grupowanie na podstawie wielu kolumn i obliczanie sumy dla każdej grupy
grupowanie_wiele_kolumn_cw = # Tu dodaj kod

# Zadanie 3: Grupowanie i obliczanie różnych statystyk dla każdej grupy
grupowanie_statystyki_cw = # Tu dodaj kod

# Wyświetlenie wyników
print("Wynik grupowania na podstawie jednej kolumny:\n", grupowanie_jedna_kolumna_cw)
print("Wynik grupowania na podstawie wielu kolumn:\n", grupowanie_wiele_kolumn_cw)
print("Wynik grupowania z różnymi operacjami dla każdej grupy:\n", grupowanie_statystyki_cw)
